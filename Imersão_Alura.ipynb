# %% [markdown]
# <a href="https://colab.research.google.com/github/GabrielJunqueira/Imersao-Dados-Alura-/blob/main/Imers%C3%A3o_Alura.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
url = "https://gist.githubusercontent.com/tgcsantos/3bdb29eba6ce391e90df2b72205ba891/raw/22fa920e80c9fa209a9fccc8b52d74cc95d1599b/dados_imoveis.csv"
dados = pd.read_csv(url)
dados.head()
# Out:
#                               Rua              Bairro     Cidade  Metragem  \
# 0           Avenida Itacira, 255    Planalto Paulista  São Paulo      1000
# 1  Rua Aurelia Perez Alvarez, 42   Jardim dos Estados  São Paulo       496
# 2                 Rua Alba Valdez     Jardim Reimberg  São Paulo       125
# 3                             NaN      Jardim Morumbi  São Paulo       310
# 4        Rua Tobias Barreto, 195                Mooca  São Paulo       100
#
#    Quartos  Banheiros  Vagas         Valor
# 0        4          8      6  R$ 7.000.000
# 1        4          4      4  R$ 3.700.000
# 2        4          3      2    R$ 380.000
# 3        3          2      4    R$ 685.000
# 4        3          2      2    R$ 540.000

# %%
dados.sample(10)
# Out:
#                                   Rua                  Bairro     Cidade  \
# 2983  Rua Dom Silvério Pimenta, , 63          Vila Gumercindo  São Paulo
# 2710                      Rua Noruega           Jardim Europa  São Paulo
# 924                   Rua Marcondésia    Chácara Monte Alegre  São Paulo
# 9951       Rua Rita Ferreira da Silva                 Socorro  São Paulo
# 5012             Avenida Parada Pinto  Vila Nova Cachoeirinha  São Paulo
# 7977               Rua Jorge Tibiriçá            Vila Mariana  São Paulo
# 240                   Rua Irmã Amélia           Vila Prudente  São Paulo
# 7054                  Rua Artur Thiré           Vila da Saúde  São Paulo
# 2849                    Rua Luisiânia                Brooklin  São Paulo
# 2861        Rua Leônidas Freire, 206             Vila Liviero  São Paulo
#
#       Metragem  Quartos  Banheiros  Vagas  \
# 2983        85        2          1      2
# 2710       878        4          6      8
# ...

# %%
#para pegar somente a coluna bairro
dados["Bairro"]
#pegar somente o bairro de um endereço específico
dados["Bairro"][1133]
# Out:
# 'Perdizes'

# %%
#obter informações sobre os dados de cada coluna
dados.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10008 entries, 0 to 10007
# Data columns (total 8 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Rua        6574 non-null   object
#  1   Bairro     9996 non-null   object
#  2   Cidade     10008 non-null  object
#  3   Metragem   10008 non-null  int64
#  4   Quartos    10008 non-null  int64
#  5   Banheiros  10008 non-null  int64
#  6   Vagas      10008 non-null  int64
#  7   Valor      10008 non-null  object
# dtypes: int64(4), object(4)
# memory usage: 625.6+ KB

# %%
#obter a média da metragem dos imóveis
dados["Metragem"].mean()
# Out:
# 442.30065947242207

# %%
#descobrir quantos imóveis da lista são da Vila Mariana
sum(dados["Bairro"] == "Vila Mariana")
#false = 0 e true = 1
# Out:
# 184

# %%
#tabela que é true somente para imóveis da Vila Mariana
tem_imoveis_VilaMariana = (dados["Bairro"] == "Vila Mariana")
tem_imoveis_VilaMariana
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 10003    False
# 10004    False
# 10005    False
# 10006    False
# 10007    False
# Name: Bairro, Length: 10008, dtype: bool

# %%
#tabela que apresenta somente os dados true (que são da Vila Mariana)
dados[tem_imoveis_VilaMariana]
# Out:
#                                Rua        Bairro     Cidade  Metragem  \
# 100               Rua Pero Correia  Vila Mariana  São Paulo       250
# 120   Praça Doutor Carvalho Franco  Vila Mariana  São Paulo       250
# 155     Rua Professor João Marinho  Vila Mariana  São Paulo       170
# 160                            NaN  Vila Mariana  São Paulo       228
# 334         Rua Pero Correia, 892   Vila Mariana  São Paulo       350
# ...                            ...           ...        ...       ...
# 9645               Rua Sousa Ramos  Vila Mariana  São Paulo       285
# 9701             Rua Benito Juarez  Vila Mariana  São Paulo       171
# 9737             Rua Benito Juarez  Vila Mariana  São Paulo       171
# 9807                           NaN  Vila Mariana  São Paulo       275
# 9852              Rua França Pinto  Vila Mariana  São Paulo       280
#
#       Quartos  Banheiros  Vagas         Valor
# 100         3          3      1  R$ 1.350.000
# ...

# %%
#encontra a metragem média dos imóveis da Vila Mariana
imoveisVilaMariana = dados[tem_imoveis_VilaMariana]
imoveisVilaMariana["Metragem"].mean()
# Out:
# 233.6195652173913

# %%
#obter quantidade de imóveis por bairro da lista
dados["Bairro"].value_counts()
# Out:
# Alto de Pinheiros     409
# Jardim Guedala        403
# Jardim Paulista       309
# Brooklin Paulista     247
# Jardim Europa         240
#                      ...
# Jardim das Imbuias      1
# Vila Represa            1
# Vila Nancy              1
# Sítio Represa           1
# Vila Invernada          1
# Name: Bairro, Length: 701, dtype: int64

# %%
#plotar gráfico de barras com os 10 primeiros (10 bairros com mais imóveis)
n_imoveis_bairro = dados["Bairro"].value_counts()
n_imoveis_bairro.head(10).plot.bar()

# %%
#Desafio 1: Média da Metragem por bairro 
separar_por_bairro = dados.groupby("Bairro")
media_metragem = separar_por_bairro["Metragem"].mean()
media_metragem
# Out:
# Bairro
# Aclimação           253.06
# Alto da Boa Vista   418.88
# Alto da Lapa        294.34
# Alto da Mooca       270.05
# Alto de Pinheiros   433.44
#                      ...
# Vila Água Funda     152.20
# Água Branca         191.00
# Água Fria           165.42
# Água Funda          139.00
# Água Rasa           340.25
# Name: Metragem, Length: 701, dtype: float64

# %%
#Desafio média de quartos por Bairro
quartos_por_bairro = dados.groupby("Bairro")
media_quartos = quartos_por_bairro["Quartos"].mean()
media_quartos
# Out:
# Bairro
# Aclimação           3.32
# Alto da Boa Vista   4.12
# Alto da Lapa        3.15
# Alto da Mooca       3.30
# Alto de Pinheiros   3.94
#                     ...
# Vila Água Funda     2.60
# Água Branca         3.15
# Água Fria           2.83
# Água Funda          3.00
# Água Rasa           3.50
# Name: Quartos, Length: 701, dtype: float64

# %%
media_quartos.sort_values(ascending=False).head(20)
# Out:
# Bairro
# Jardim Gonzaga                     10.00
# Vila Picinin                        9.00
# Vila Sabrina                        8.00
# Vila Gomes                          6.57
# Jardim Japão                        6.25
# Vila Liviero                        6.00
# Jardim Record                       6.00
# Jardim Castelo                      6.00
# Vila Califórnia(Zona Sul)           6.00
# Conjunto Promorar Raposo Tavares    6.00
# Parque Novo Mundo                   6.00
# Santa Cecília                       5.71
# Paraíso                             5.71
# Consolação                          5.62
# Vila Nelson                         5.00
# Rio Bonito                          5.00
# Nossa Senhora do Ó                  5.00
# Jardim Vila Carrão                  5.00
# Vila do Bosque                      5.00
# Vila Aurora (Zona Norte)            5.00
# Name: Quartos, dtype: float64

# %%
###################################################################################
###################################################################################
#AQUI COMEÇA A SEGUNDA AULA DA IMERSÃO
###################################################################################
###################################################################################

# %%
#limpar dados para converter o valor em número
dados["Valor"][0]
# Out:
# 'R$ 7.000.000'

# %%
#separar os termos do valor em strings:
dados["Valor"][0].split()
# Out:
# ['R$', '7.000.000']

# %%
#fazer isso com cada valor da tabela
dados["Valor"].str.split()
# Out:
# 0          [R$, 7.000.000]
# 1          [R$, 3.700.000]
# 2            [R$, 380.000]
# 3            [R$, 685.000]
# 4            [R$, 540.000]
#                ...
# 10003        [R$, 665.000]
# 10004      [R$, 2.300.000]
# 10005      [R$, 1.050.000]
# 10006    [R$, 2.200, /Mês]
# 10007        [R$, 270.000]
# Name: Valor, Length: 10008, dtype: object

# %%
#colocar o obtido em colunas 
dados["Valor"].str.split(expand = True)
# Out:
#         0          1     2
# 0      R$  7.000.000  None
# 1      R$  3.700.000  None
# 2      R$    380.000  None
# 3      R$    685.000  None
# 4      R$    540.000  None
# ...    ..        ...   ...
# 10003  R$    665.000  None
# 10004  R$  2.300.000  None
# 10005  R$  1.050.000  None
# 10006  R$      2.200  /Mês
# 10007  R$    270.000  None
#
# [10008 rows x 3 columns]

# %%
#verificar se na primeira coluna só tem 'R$' mesmo
dados["Valor"].str.split(expand = True)[0].unique()
# Out:
# array(['R$'], dtype=object)

# %%
#Agora vou adicionar essas 3 colunas que obtive à nossa antiga grande tabela
dados[["Moeda", "Valor_Anuncio", "Tipo_Anuncio"]] = dados["Valor"].str.split(expand = True)
dados.head()
# Out:
#                               Rua              Bairro     Cidade  Metragem  \
# 0           Avenida Itacira, 255    Planalto Paulista  São Paulo      1000
# 1  Rua Aurelia Perez Alvarez, 42   Jardim dos Estados  São Paulo       496
# 2                 Rua Alba Valdez     Jardim Reimberg  São Paulo       125
# 3                             NaN      Jardim Morumbi  São Paulo       310
# 4        Rua Tobias Barreto, 195                Mooca  São Paulo       100
#
#    Quartos  Banheiros  Vagas         Valor Moeda Valor_Anuncio Tipo_Anuncio
# 0        4          8      6  R$ 7.000.000    R$     7.000.000         None
# 1        4          4      4  R$ 3.700.000    R$     3.700.000         None
# 2        4          3      2    R$ 380.000    R$       380.000         None
# 3        3          2      4    R$ 685.000    R$       685.000         None
# 4        3          2      2    R$ 540.000    R$       540.000         None

# %%
#agora vamos eliminar os Tipos de Anuncio que não são vazios - essas linhas correspondem a anuncios de aluguel
dados["Tipo_Anuncio"].isnull()
#aqui obtenho todos que são vazios ou não - quero remover os que não estão vazios
#obtendo uma tabela só com os que estão true (os que são nulos):
dados[dados["Tipo_Anuncio"].isnull()]
# Out:
#                                   Rua              Bairro     Cidade  \
# 0               Avenida Itacira, 255    Planalto Paulista  São Paulo
# 1      Rua Aurelia Perez Alvarez, 42   Jardim dos Estados  São Paulo
# 2                     Rua Alba Valdez     Jardim Reimberg  São Paulo
# 3                                 NaN      Jardim Morumbi  São Paulo
# 4            Rua Tobias Barreto, 195                Mooca  São Paulo
# ...                               ...                 ...        ...
# 10002                   Avenida Odila   Planalto Paulista  São Paulo
# 10003                      Rua Tapuçu          Vila Sofia  São Paulo
# 10004                   Rua Guararema     Bosque da Saúde  São Paulo
# 10005               Rua Estero Belaco       Vila da Saúde  São Paulo
# 10007      Rua Barão de Tramandaí, 0          Vila Alpina  São Paulo
#
#        Metragem  Quartos  Banheiros  Vagas         Valor Moeda Valor_Anuncio  \
# ...

# %%
#nova tabela sem os anuncios de aluguel
dados_filtrados1 = dados[dados["Tipo_Anuncio"].isnull()]
dados_filtrados1.head()
# Out:
#                               Rua              Bairro     Cidade  Metragem  \
# 0           Avenida Itacira, 255    Planalto Paulista  São Paulo      1000
# 1  Rua Aurelia Perez Alvarez, 42   Jardim dos Estados  São Paulo       496
# 2                 Rua Alba Valdez     Jardim Reimberg  São Paulo       125
# 3                             NaN      Jardim Morumbi  São Paulo       310
# 4        Rua Tobias Barreto, 195                Mooca  São Paulo       100
#
#    Quartos  Banheiros  Vagas         Valor Moeda Valor_Anuncio Tipo_Anuncio
# 0        4          8      6  R$ 7.000.000    R$     7.000.000         None
# 1        4          4      4  R$ 3.700.000    R$     3.700.000         None
# 2        4          3      2    R$ 380.000    R$       380.000         None
# 3        3          2      4    R$ 685.000    R$       685.000         None
# 4        3          2      2    R$ 540.000    R$       540.000         None

# %%
#agora vamos transfomar Valor Anuncio em um tipo numérico - ele está em string
#primeiro temos que eliminar esse ponto que dificulta a conversão (7.000.000 -> 7000000)
dados_filtrados1["Valor_Anuncio"].str.replace(".","")
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   This is separate from the ipykernel package so we can avoid doing imports until
# 0        7000000
# 1        3700000
# 2         380000
# 3         685000
# 4         540000
#           ...
# 10002    1500000
# 10003     665000
# 10004    2300000
# 10005    1050000
# 10007     270000
# Name: Valor_Anuncio, Length: 9156, dtype: object

# %%
dados_filtrados1["Valor_Anuncio"].str.replace(".","")
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   """Entry point for launching an IPython kernel.
# 0        7000000
# 1        3700000
# 2         380000
# 3         685000
# 4         540000
#           ...
# 10002    1500000
# 10003     665000
# 10004    2300000
# 10005    1050000
# 10007     270000
# Name: Valor_Anuncio, Length: 9156, dtype: object

# %%
#Agora convertemos todos esses valores para o tipo float
dados_filtrados1["Valor_Anuncio"].str.replace(".","").astype(float)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
# 0       7000000.00
# 1       3700000.00
# 2        380000.00
# 3        685000.00
# 4        540000.00
#            ...
# 10002   1500000.00
# 10003    665000.00
# 10004   2300000.00
# 10005   1050000.00
# 10007    270000.00
# Name: Valor_Anuncio, Length: 9156, dtype: float64

# %%
#Em seguida, adicionamos essa coluna de tipo float à nossa tabela
dados_filtrados1["Valor_Anuncio_float"] = dados_filtrados1["Valor_Anuncio"].str.replace(".","").astype(float)
dados_filtrados1.head()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#                               Rua              Bairro     Cidade  Metragem  \
# 0           Avenida Itacira, 255    Planalto Paulista  São Paulo      1000
# 1  Rua Aurelia Perez Alvarez, 42   Jardim dos Estados  São Paulo       496
# 2                 Rua Alba Valdez     Jardim Reimberg  São Paulo       125
# ...

# %%
#o método describe() pega todas as colunas numéricas e traz uma série de informação
dados_filtrados1.describe()
# Out:
#        Metragem  Quartos  Banheiros   Vagas  Valor_Anuncio_float
# count   9156.00  9156.00    9156.00 9156.00              9156.00
# mean     434.42     3.45       3.80    3.96           3052202.96
# std     7856.42     1.05       1.97    2.60           3944208.19
# min       10.00     1.00       1.00    1.00             13000.00
# 25%      168.00     3.00       2.00    2.00            890000.00
# 50%      276.00     3.00       4.00    4.00           1800000.00
# 75%      450.00     4.00       5.00    5.00           3500000.00
# max   750000.00    16.00      40.00   50.00          65000000.00

# %%
#arrumando a precisão para somente duas casas decimais
pd.set_option("display.float_format", lambda x: '%.2f' % x)
dados_filtrados1.describe()
# Out:
#        Metragem  Quartos  Banheiros   Vagas  Valor_Anuncio_float
# count   9156.00  9156.00    9156.00 9156.00              9156.00
# mean     434.42     3.45       3.80    3.96           3052202.96
# std     7856.42     1.05       1.97    2.60           3944208.19
# min       10.00     1.00       1.00    1.00             13000.00
# 25%      168.00     3.00       2.00    2.00            890000.00
# 50%      276.00     3.00       4.00    4.00           1800000.00
# 75%      450.00     4.00       5.00    5.00           3500000.00
# max   750000.00    16.00      40.00   50.00          65000000.00

# %%
#usando seaborn (biblioteca para plotagem de gráficos)
import seaborn as sns
import matplotlib.pyplot as plt

sns.set()
plt.figure(figsize=(10, 8))
ax = sns.histplot(data = dados_filtrados1, x = "Valor_Anuncio_float", kde = True)
ax.set_title("Histograma Valor Imóvel")
#kde = True para colocar a curva de comportamento do gráfico
# Out:
# Text(0.5, 1.0, 'Histograma Valor Imóvel')

# %%
###################################################################################
###################################################################################
#AQUI COMEÇA A TERCEIRA AULA DA IMERSÃO
###################################################################################
###################################################################################

# %%
#obtendo o preço do m^2 por bairro
dados_filtrados1["Valor_Anuncio_float"]/dados_filtrados1["Metragem"]
# Out:
# 0       7000.00
# 1       7459.68
# 2       3040.00
# 3       2209.68
# 4       5400.00
#           ...
# 10002   5617.98
# 10003   7000.00
# 10004   3801.65
# 10005   5121.95
# 10007   2213.11
# Length: 9156, dtype: float64

# %%
#criando uma nova coluna Valor m2
dados_filtrados1["Valor_m2"] = dados_filtrados1["Valor_Anuncio_float"]/dados_filtrados1["Metragem"]
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
dados_filtrados1.groupby("Bairro").mean()
# Out:
#                    Metragem  Quartos  Banheiros  Vagas  Valor_Anuncio_float  \
# Bairro
# Aclimação            246.16     3.27       3.04   2.91           1763200.01
# Alto da Boa Vista    418.88     4.12       5.12   4.62           2391250.00
# Alto da Lapa         299.25     3.15       3.85   4.00           2083168.75
# Alto da Mooca        270.05     3.30       2.60   3.65           1184170.00
# Alto de Pinheiros    429.85     3.94       4.83   4.95           4782698.96
# ...                     ...      ...        ...    ...                  ...
# Vila Água Funda      152.20     2.60       2.20   2.60            652000.00
# Água Branca          173.58     3.08       3.25   2.25           1226500.00
# Água Fria            165.42     2.83       3.42   2.50            927083.33
# Água Funda           139.00     3.00       2.50   2.00            545000.00
# Água Rasa            186.17     2.67       2.00   3.67            716166.67
#
#                    Valor_m2
# Bairro
# ...

# %%
dados_filtrados1.groupby("Bairro").sum()
dados_bairro_soma = dados_filtrados1.groupby("Bairro").sum()
dados_bairro_soma["Valor_m2_bairro"] = dados_bairro_soma["Valor_Anuncio_float"]/dados_bairro_soma["Metragem"]
dados_bairro_soma.head()
# Out:
#                    Metragem  Quartos  Banheiros  Vagas  Valor_Anuncio_float  \
# Bairro
# Aclimação             19447      258        240    230         139292801.00
# Alto da Boa Vista      3351       33         41     37          19130000.00
# Alto da Lapa          23940      252        308    320         166653500.00
# Alto da Mooca          5401       66         52     73          23683400.00
# Alto de Pinheiros    158616     1453       1782   1827        1764815915.00
#
#                     Valor_m2  Valor_m2_bairro
# Bairro
# Aclimação          604837.39          7162.69
# Alto da Boa Vista   46796.55          5708.74
# Alto da Lapa       608538.25          6961.30
# Alto da Mooca      113834.80          4385.00
# Alto de Pinheiros 4158622.61         11126.34

# %%
#Localizar dados de um bairro específico:
dados_bairro_soma.loc["Vila Mariana"]
# Out:
# Metragem                  39079.00
# Quartos                     573.00
# Banheiros                   547.00
# Vagas                       499.00
# Valor_Anuncio_float   299326000.00
# Valor_m2                1337323.16
# Valor_m2_bairro            7659.51
# Name: Vila Mariana, dtype: float64

# %%
#Agora vamos plotar alguns gráficos, como são muitos bairros, podemos filtrar alguns deles
#vamos selecionar os bairros mais frequentes primeiro
#value counts aqui ordena os bairros que mais aparecem na tabela
dados_filtrados1["Bairro"].value_counts()
# Out:
# Alto de Pinheiros      369
# Jardim Guedala         353
# Jardim Paulista        266
# Brooklin Paulista      224
# Jardim Europa          210
#                       ...
# Vila Virginia            1
# Vila Boaçava             1
# Vila Agueda              1
# Jardim Monte Alegre      1
# Jardim Ivana             1
# Name: Bairro, Length: 697, dtype: int64

# %%
#pegando só os 10 primeiros da lista:
top_bairros = dados_filtrados1["Bairro"].value_counts()[0:10].index
top_bairros
#esses são os bairros com mais imóveis listados na tabela
# Out:
# Index(['Alto de Pinheiros', 'Jardim Guedala', 'Jardim Paulista',
#        'Brooklin Paulista', 'Jardim Europa', 'Pacaembu', 'Vila Madalena',
#        'Cidade Jardim', 'Planalto Paulista', 'Jardim Leonor'],
#       dtype='object')

# %%
#arrumando o index da tabela (deixa de ser coluna bairro e passa a ser números mesmo)
dados_bairro_soma = dados_bairro_soma.reset_index()
dados_bairro_soma.head()
# Out:
#               Bairro  Metragem  Quartos  Banheiros  Vagas  \
# 0          Aclimação     19447      258        240    230
# 1  Alto da Boa Vista      3351       33         41     37
# 2       Alto da Lapa     23940      252        308    320
# 3      Alto da Mooca      5401       66         52     73
# 4  Alto de Pinheiros    158616     1453       1782   1827
#
#    Valor_Anuncio_float   Valor_m2  Valor_m2_bairro
# 0         139292801.00  604837.39          7162.69
# 1          19130000.00   46796.55          5708.74
# 2         166653500.00  608538.25          6961.30
# 3          23683400.00  113834.80          4385.00
# 4        1764815915.00 4158622.61         11126.34

# %%
#seleciinonar somente os bairros com mais imóveis listados na tabela
dados_bairro_soma.query("Bairro in @top_bairros")
# Out:
#                 Bairro  Metragem  Quartos  Banheiros  Vagas  \
# 4    Alto de Pinheiros    158616     1453       1782   1827
# 19   Brooklin Paulista     70002      778        862    832
# 57       Cidade Jardim    132220      789       1008   1172
# 155      Jardim Europa    118898      795        993   1056
# 168     Jardim Guedala    972212     1443       2027   2161
# 187      Jardim Leonor     97141      697        941    902
# 227    Jardim Paulista    130283     1028       1231   1171
# 338           Pacaembu    100285      774        889   1028
# 396  Planalto Paulista     59250      636        768    713
# 564      Vila Madalena     66250      739        786    712
#
#      Valor_Anuncio_float   Valor_m2  Valor_m2_bairro
# 4          1764815915.00 4158622.61         11126.34
# 19          475796789.00 1627341.87          6796.90
# 57         1164210900.00 1635692.98          8805.10
# 155        2414172900.00 4192164.45         20304.57
# ...

# %%
plt.figure(figsize=(10, 8))
ax = sns.barplot(x="Bairro", y="Valor_m2_bairro", data=dados_bairro_soma.query("Bairro in @top_bairros"))

# %%
#arrumando os indices que estão se sobrepondo
plt.figure(figsize=(10, 8))
ax = sns.barplot(x="Bairro", y="Valor_m2_bairro", data=dados_bairro_soma.query("Bairro in @top_bairros"))
ax.tick_params(axis='x' , rotation=90)

# %%
###################################################################################
###################################################################################
#AQUI COMEÇA A QUARTA AULA DA IMERSÃO
###################################################################################
###################################################################################

# %%
import pandas as pd
ibge_sp = pd.read_csv(
    'https://gist.githubusercontent.com/tgcsantos/85f8c7b0a2edbc3e27fcad619b37d886/raw/a4954781e6bca9cb804062a3eea0b3b84679daf4/Basico_SP1.csv',
    encoding='ISO-8859-1',
    sep=';', thousands='.', decimal=','
)
ibge_sp.dropna(how='all', axis=1, inplace=True)
ibge_sp.head()
# Out:
#          Cod_setor  Cod_Grandes Regiï¿½es Nome_Grande_Regiao  Cod_UF  \
# 0  355030801000001                      3   Regiï¿½o Sudeste      35
# 1  355030801000002                      3   Regiï¿½o Sudeste      35
# 2  355030801000003                      3   Regiï¿½o Sudeste      35
# 3  355030801000004                      3   Regiï¿½o Sudeste      35
# 4  355030801000005                      3   Regiï¿½o Sudeste      35
#
#    Nome_da_UF   Cod_meso                  Nome_da_meso  Cod_micro  \
# 0  Sï¿½o Paulo      3515  Metropolitana de Sï¿½o Paulo      35061
# 1  Sï¿½o Paulo      3515  Metropolitana de Sï¿½o Paulo      35061
# 2  Sï¿½o Paulo      3515  Metropolitana de Sï¿½o Paulo      35061
# 3  Sï¿½o Paulo      3515  Metropolitana de Sï¿½o Paulo      35061
# 4  Sï¿½o Paulo      3515  Metropolitana de Sï¿½o Paulo      35061
#
#   Nome_da_micro  Cod_RM  ... V003  V004    V005       V006    V007       V008  \
# ...

# %%
enderecos = pd.read_csv("/content/drive/MyDrive/Cópia de enderecos.csv")
enderecos.head()
# Out:
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:2882: DtypeWarning: Columns (3) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
#   tipo_logr                      logr_nome  \
# 0       Rua               Armando Silveira
# 1       Rua       João Antônio Vasconcelos
# 2       Rua  Prefeito Agenor Barcelos Feio
# 3       Rua                Sebastião Gomes
# 4       Rua            Marquês do Alegrete
#
#                                    logr_compl numero            bairro  \
# 0                        Rua Armando Silveira    NaN            Divisa
# 1  Rua João Antônio Vasconcelos - até 627/628    627           Amizade
# 2           Rua Prefeito Agenor Barcelos Feio    NaN          Registro
# 3             Rua Sebastião Gomes - até 59/60     59          Registro
# 4                     Rua Marquês do Alegrete    NaN  Parque das Águas
#
# ...

# %%
#filtrando para obter somente endereços de SP da tabela
enderecos_sp = enderecos.query("sigla_uf == 'SP'")

# %%
#criando uma nova coluna que une tipo_logr com logr_nome
enderecos_sp["rua"] = enderecos_sp["tipo_logr"] + " " + enderecos_sp["logr_nome"] 
#deixar tudo em minúsculo e eliminar espaços extras
enderecos_sp["rua"] = enderecos_sp["rua"].str.lower().str.strip()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.

# %%
#na antiga tabela dados filtrados, extraímos o número e vírgulas dos endereços
dados_filtrados1["Rua"].str.extract(r'(^[\w ]+)')[:10]
# Out:
#                            0
# 0            Avenida Itacira
# 1  Rua Aurelia Perez Alvarez
# 2            Rua Alba Valdez
# 3                        NaN
# 4         Rua Tobias Barreto
# 5            Rua Graham Bell
# 6        Rua Francisco Paulo
# 7      Rua Guilherme Valente
# 8        Rua Sagrada Família
# 9                 Rua Tapaji

# %%
#adicionando o que foi obtido a uma nova coluna
dados_filtrados1["apenas_rua"] = dados_filtrados1["Rua"].str.extract(r'(^[\w ]+)')
dados_filtrados1["apenas_rua"] = dados_filtrados1["apenas_rua"].str.lower().str.strip()
dados_filtrados1.head()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
#                               Rua              Bairro     Cidade  Metragem  \
# 0           Avenida Itacira, 255    Planalto Paulista  São Paulo      1000
# ...

# %%
#juntando as duas tabelas que tenho, adicionando a dados_filtrados1 mais dados de rua, cep, latitude, longitude provenientes de enderecos_sp
#essa junção é feita a partir do nome da rua
dados_geo = pd.merge(left = dados_filtrados1, right = enderecos_sp[["rua", "cep", "latitude", "longitude"]], how = "left", left_on = "apenas_rua", right_on = "rua")

# %%
#removendo linhas duplicadas que podem ter aparecido nessa nova tabela:
dados_geo = pd.merge(left = dados_filtrados1, right = enderecos_sp[["rua", "cep", "latitude", "longitude"]], how = "left", left_on = "apenas_rua", right_on = "rua").drop_duplicates(subset=dados_filtrados1
.columns).query("cep > 0")

# %%
from shapely.geometry import Point
latitude = -23.56 	
longitude = -46.59
Point(longitude, latitude)
from shapely.geometry import Polygon
Polygon([[0, 0], [1, 0], [1, 1], [0, 1], [0, 0]])

# %%
# !pip install geopandas
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
import geopandas as gpd

# %%
setor_censo = gpd.read_file(
'/content/drive/MyDrive/Colab Notebooks/sp_setores_censitarios/35SEE250GC_SIR.shp'
)
setor_censo.head()
# Out:
#         ID       CD_GEOCODI    TIPO   CD_GEOCODS NM_SUBDIST CD_GEOCODD  \
# 0 98237.00  354100005000009  URBANO  35410000500       None  354100005
# 1 98232.00  354100005000004  URBANO  35410000500       None  354100005
# 2 98230.00  354100005000002  URBANO  35410000500       None  354100005
# 3 98229.00  354100005000001  URBANO  35410000500       None  354100005
# 4 98231.00  354100005000003  URBANO  35410000500       None  354100005
#
#      NM_DISTRIT CD_GEOCODM    NM_MUNICIP NM_MICRO                     NM_MESO  \
# 0  PRAIA GRANDE    3541000  PRAIA GRANDE   SANTOS  METROPOLITANA DE SÃO PAULO
# 1  PRAIA GRANDE    3541000  PRAIA GRANDE   SANTOS  METROPOLITANA DE SÃO PAULO
# 2  PRAIA GRANDE    3541000  PRAIA GRANDE   SANTOS  METROPOLITANA DE SÃO PAULO
# 3  PRAIA GRANDE    3541000  PRAIA GRANDE   SANTOS  METROPOLITANA DE SÃO PAULO
# 4  PRAIA GRANDE    3541000  PRAIA GRANDE   SANTOS  METROPOLITANA DE SÃO PAULO
#
#      CD_GEOCODB  NM_BAIRRO  ID1  \
# 0  354100005001  Boqueirão    1
# ...

# %%
#filtrando a tabela acima só para endereços da cidade de São Paulo
setor_censo_sp = setor_censo[setor_censo.NM_MUNICIP == "SÃO PAULO"]
setor_censo_sp[setor_censo_sp.contains(Point(-46.63, -23.58))]
# Out:
#              ID       CD_GEOCODI    TIPO   CD_GEOCODS NM_SUBDIST CD_GEOCODD  \
# 60986 126568.00  355030890000080  URBANO  35503089000       None  355030890
#
#          NM_DISTRIT CD_GEOCODM NM_MUNICIP   NM_MICRO  \
# 60986  VILA MARIANA    3550308  SÃO PAULO  SÃO PAULO
#
#                           NM_MESO CD_GEOCODB NM_BAIRRO    ID1  \
# 60986  METROPOLITANA DE SÃO PAULO       None      None  60987
#
#                                                 geometry
# 60986  POLYGON ((-46.62618 -23.58169, -46.62863 -23.5...

# %%
#criando a variável Point
#para cada latitude e longitude, crio um ponto na base de dados 
dados_geo["Point"] = ""
for i in dados_geo.index:
    dados_geo["Point"][i] = Point(dados_geo["longitude"][i], dados_geo["latitude"][i])
#Pegando cada um dos pontos e procurando na base censitária criada
#perguntando se esse ponto está ou não no polígono e retornando o código censitário 
dados_geo['setor_censo'] = dados_geo["Point"][:10].map(
    lambda x: setor_censo_sp.loc[setor_censo_sp.contains(x), 'CD_GEOCODI'].values
).str[0]
dados_geo
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """
#                                   Rua              Bairro     Cidade  \
# 0               Avenida Itacira, 255    Planalto Paulista  São Paulo
# 5      Rua Aurelia Perez Alvarez, 42   Jardim dos Estados  São Paulo
# 6                     Rua Alba Valdez     Jardim Reimberg  São Paulo
# 7                                 NaN      Jardim Morumbi  São Paulo
# 26           Rua Tobias Barreto, 195                Mooca  São Paulo
# ...                               ...                 ...        ...
# 89956                   Avenida Odila   Planalto Paulista  São Paulo
# 89958                      Rua Tapuçu          Vila Sofia  São Paulo
# ...

# %%
dados_geo = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/dados_geo.csv")
dados_geo.head()
# Out:
#                               Rua              Bairro     Cidade  Metragem  \
# 0           Avenida Itacira, 255    Planalto Paulista  São Paulo      1000
# 1  Rua Aurelia Perez Alvarez, 42   Jardim dos Estados  São Paulo       496
# 2                 Rua Alba Valdez     Jardim Reimberg  São Paulo       125
# 3        Rua Tobias Barreto, 195                Mooca  São Paulo       100
# 4                 Rua Graham Bell         Santo Amaro  São Paulo       440
#
#    Quartos  Banheiros  Vagas         Valor  Valor_anuncio  Tipo_anuncio  \
# 0        4          8      6  R$ 7.000.000     7000000.00           NaN
# 1        4          4      4  R$ 3.700.000     3700000.00           NaN
# 2        4          3      2    R$ 380.000      380000.00           NaN
# 3        3          2      2    R$ 540.000      540000.00           NaN
# 4        4          4      6  R$ 1.980.000     1980000.00           NaN
#
#    Valor_mm  Valor_m2                        rua        cep  latitude  \
# ...

# %%
#dados vendas finalmente junto com dados do censo!
dados_vendas_censo = pd.merge(left = dados_geo, right = ibge_sp, how = "left", left_on = "setor_censo", right_on = "Cod_setor")
dados_vendas_censo
# Out:
#                                  Rua              Bairro     Cidade  Metragem  \
# 0              Avenida Itacira, 255    Planalto Paulista  São Paulo      1000
# 1     Rua Aurelia Perez Alvarez, 42   Jardim dos Estados  São Paulo       496
# 2                    Rua Alba Valdez     Jardim Reimberg  São Paulo       125
# 3           Rua Tobias Barreto, 195                Mooca  São Paulo       100
# 4                    Rua Graham Bell         Santo Amaro  São Paulo       440
# ...                              ...                 ...        ...       ...
# 5600                   Avenida Odila   Planalto Paulista  São Paulo       267
# 5601                      Rua Tapuçu          Vila Sofia  São Paulo        95
# 5602                   Rua Guararema     Bosque da Saúde  São Paulo       605
# 5603               Rua Estero Belaco       Vila da Saúde  São Paulo       205
# 5604      Rua Barão de Tramandaí, 0          Vila Alpina  São Paulo       122
#
# ...

# %%
#comparando o valor do metro quadrado com a renda de casa pessoa (respondido na pergunta V005 do ibge)
plt.figure(figsize=(10, 10))
sns.scatterplot(data = dados_vendas_censo, x="V005", y="Valor_m2")

# %%
###################################################################################
###################################################################################
#AQUI COMEÇA A QUINTA AULA DA IMERSÃO
###################################################################################
###################################################################################

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

pd.set_option("display.precision", 2)
pd.set_option('display.float_format', lambda x: '%.2f' % x)
sns.set()

#selecionando somente os campos desejados
dados_vendas_censo = dados_vendas_censo[['Rua', 'Bairro', 'Cidade', 'Metragem', 'Quartos', 'Banheiros', 'Vagas',
       'Valor_anuncio', 'Valor_mm', 'Valor_m2', 'latitude', 'longitude', 'Situacao_setor', 'V001',
       'V002', 'V003', 'V004', 'V005', 'V006', 'V007', 'V008', 'V009', 'V010',
       'V011', 'V012']].dropna()
dados_vendas_censo
# Out:
#                                  Rua              Bairro     Cidade  Metragem  \
# 0              Avenida Itacira, 255    Planalto Paulista  São Paulo      1000
# 1     Rua Aurelia Perez Alvarez, 42   Jardim dos Estados  São Paulo       496
# 2                    Rua Alba Valdez     Jardim Reimberg  São Paulo       125
# 3           Rua Tobias Barreto, 195                Mooca  São Paulo       100
# 4                    Rua Graham Bell         Santo Amaro  São Paulo       440
# ...                              ...                 ...        ...       ...
# 5599              Rua Pedro Teixeira        Vila Olímpia  São Paulo       157
# 5600                   Avenida Odila   Planalto Paulista  São Paulo       267
# 5601                      Rua Tapuçu          Vila Sofia  São Paulo        95
# 5603               Rua Estero Belaco       Vila da Saúde  São Paulo       205
# 5604      Rua Barão de Tramandaí, 0          Vila Alpina  São Paulo       122
#
# ...

# %%
#procurando por imóveis cujos valores ultrapassam 30 milhões ou são inferiores a 100 mil
dados_vendas_censo.query("Valor_anuncio > 30000000 | Valor_anuncio < 100000")
# Out:
#                        Rua          Bairro     Cidade  Metragem  Quartos  \
# 54          Rua Inglaterra   Jardim Europa  São Paulo       200        3
# 89          Rua Inglaterra   Jardim Europa  São Paulo       756        5
# 1032  Praça Nicolau Scarpa  Jardim América  São Paulo      1200        4
# 3521    Rua Estados Unidos  Jardim América  São Paulo      1816        4
# 3896    Rua Estados Unidos  Jardim América  São Paulo      1200        4
#
#       Banheiros  Vagas  Valor_anuncio  Valor_mm  Valor_m2  ...  V003  V004  \
# 54            3      2       13000.00      0.01     65.00  ...  3.13  2.87
# 89            4     10    37000000.00     37.00  48941.80  ...  3.13  2.87
# 1032          4     25    65000000.00     65.00  54166.67  ...  3.57  3.01
# 3521         10     20    55000000.00     55.00  30286.34  ...  3.57  3.01
# 3896          6     24    65000000.00     65.00  54166.67  ...  3.57  3.01
#
#          V005          V006     V007          V008     V009         V010  \
# ...

# %%
#removendo esses imóveis encontrados acima
dados_vendas_censo.drop(dados_vendas_censo.query("Valor_anuncio > 30000000 | Valor_anuncio < 100000").index, inplace = True)

# %%
plt.figure(figsize=(18, 8))
#https://www.tylervigen.com/spurious-correlations
mask = np.triu(np.ones_like(dados_vendas_censo.corr(), dtype=bool))
heatmap = sns.heatmap(dados_vendas_censo.corr(), mask=mask, vmin=-1, vmax=1, annot=True, cmap='BrBG')
heatmap.set_title('Correlação', fontdict={'fontsize':18}, pad=16);

# %%
#preparando para treinar um modelo de regressão linear
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

X = dados_vendas_censo[["Metragem"]]
Y = dados_vendas_censo["Valor_anuncio"]

X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size = 0.25, random_state = 54)
lr = LinearRegression()

# %%
#o treino é feito com certos dados X_train e Y_train
lr.fit(X_train, Y_train)
# Out:
# LinearRegression()

# %%
lr.predict(X_test)
# Out:
# array([4535135.54576314, 2319529.74583429, 2424501.59358835, ...,
#        2802400.24550293, 2483285.82833061, 2854186.3570616 ])

# %%
#ao fazer regressão linear com somente duas variáveis um resultado ruim é obtido
#fazê-la a partir de mais variáveis faz com que no predição fique mais exata
from sklearn.metrics import mean_absolute_error, r2_score
X = dados_vendas_censo[['Metragem', 'Quartos', 'Banheiros', 'Vagas','V001','V007', 'V009']]

Y = dados_vendas_censo["Valor_anuncio"]

X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size = 0.25, random_state = 54)
lr.fit(X_train, Y_train)
Y_predict_test = lr.predict(X_test)
Y_predict_train = lr.predict(X_train)
mae_test = mean_absolute_error(Y_test, Y_predict_test)
r2_test = r2_score(Y_test, Y_predict_test)
mae_train = mean_absolute_error(Y_train, Y_predict_train)
r2_train = r2_score(Y_train, Y_predict_train)

# %%
#obtemos o seguinte mean absolute error
mae_test
# Out:
# 1349590.384432537

# %%
#obtemos o seguinte r^2
r2_test
# Out:
# 0.37745069254620534
